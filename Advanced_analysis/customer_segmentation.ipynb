# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.cluster import KMeans

def customer_segmentation(df):
    # Aggregate metrics
    business_metrics = df.groupby('ANONYMIZED BUSINESS').agg({
        'QUANTITY': 'sum',
        'Total_Value': 'sum',
        'DATE': 'count'  # Frequency of transactions
    }).rename(columns={'DATE': 'Frequency'}).reset_index()

    # Normalize metrics
    scaler = MinMaxScaler()
    metrics_scaled = scaler.fit_transform(business_metrics[['QUANTITY', 'Total_Value', 'Frequency']])
    
    # Clustering with KMeans
    kmeans = KMeans(n_clusters=3, random_state=42)
    business_metrics['Segment'] = kmeans.fit_predict(metrics_scaled)

    # Label segments (e.g., High Value, Medium Value, Low Value)
    segment_labels = {0: 'High Value', 1: 'Medium Value', 2: 'Low Value'}
    business_metrics['Segment'] = business_metrics['Segment'].map(segment_labels)

    return business_metrics

# Perform segmentation
df = pd.read_csv('../cleaned_data.csv')

# Ensure Total_Value is correctly calculated if missing
if 'Total_Value' not in df.columns:
    df['Total_Value'] = df['QUANTITY'] * df['UNIT PRICE']

# Drop the previous Segment columns if they exist
if 'Segment_x' in df.columns or 'Segment_y' in df.columns:
    df = df.drop(columns=['Segment_x', 'Segment_y'], errors='ignore')

# Perform segmentation and merge
segmented_customers = customer_segmentation(df)
df_with_segments = df.merge(segmented_customers[['ANONYMIZED BUSINESS', 'Segment']], 
                            on='ANONYMIZED BUSINESS', 
                            how='left')

# Save the updated DataFrame with segmentation to a new CSV file
df_with_segments.to_csv('../cleaned_data.csv', index=False)

# Print a preview
print("\n******Cleaned Data with Segments*******\n")
print(df_with_segments.head(50))
# Out:
# /home/moses/.local/lib/python3.8/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# ******Cleaned Data with Segments*******
#
#                    DATE ANONYMIZED CATEGORY ANONYMIZED PRODUCT  \
# 0   2024-08-18 21:32:00        Category-106       Product-21f4
# 1   2024-08-18 21:32:00        Category-120       Product-4156
# 2   2024-08-18 21:32:00        Category-121       Product-49bd
# 3   2024-08-18 21:32:00         Category-76       Product-61dd
# 4   2024-08-18 21:32:00        Category-119       Product-66e0
# 5   2024-08-18 21:32:00         Category-76       Product-6e9c
# 6   2024-08-18 21:32:00        Category-120       Product-7864
# 7   2024-08-18 21:32:00        Category-119       Product-7940
# 8   2024-08-18 21:32:00         Category-96       Product-87b2
# 9   2024-08-18 21:32:00        Category-106       Product-c14c
# 10  2024-08-06 19:36:00        Category-100       Product-3cc2
# 11  2024-08-06 19:36:00         Category-85       Product-5ab4
# 12  2024-06-23 19:37:00        Category-120       Product-14f3
# 13  2024-06-23 19:37:00         Category-75       Product-8f75
# 14  2024-11-25 16:42:00         Category-82       Product-91f3
# 15  2024-11-25 16:42:00         Category-77       Product-b1c8
# 16  2024-11-25 16:42:00         Category-78       Product-b409
# 17  2024-09-06 08:42:00         Category-75       Product-6aa1
# 18  2024-09-06 08:42:00         Category-76       Product-c570
# 19  2024-09-06 08:42:00        Category-100       Product-f3ee
# 20  2024-10-27 21:05:00         Category-95       Product-766b
# 21  2024-09-05 19:48:00        Category-120       Product-14f3
# 22  2024-09-05 19:48:00        Category-120       Product-9a3e
# 23  2024-05-23 20:22:00         Category-75       Product-086d
# 24  2024-05-23 20:22:00         Category-91       Product-32b3
# 25  2024-05-23 20:22:00         Category-85       Product-5ab4
# 26  2024-05-23 20:22:00        Category-107       Product-8d56
# 27  2024-05-23 20:22:00        Category-113       Product-9c60
# 28  2024-05-23 20:22:00         Category-76       Product-e805
# 29  2024-09-27 21:33:00         Category-94       Product-77bc
# 30  2024-09-27 21:33:00         Category-94       Product-9c81
# 31  2024-09-27 21:33:00         Category-76       Product-e805
# 32  2024-09-27 21:33:00         Category-84       Product-ee8b
# 33  2024-02-02 16:27:00         Category-94       Product-703d
# 34  2024-02-02 16:27:00         Category-77       Product-d09c
# 35  2024-06-05 21:39:00        Category-119       Product-66e0
# 36  2024-06-05 21:39:00         Category-75       Product-faa5
# 37  2024-09-12 09:00:00         Category-94       Product-6491
# 38  2024-09-12 09:00:00         Category-75       Product-8b75
# 39  2024-11-03 15:58:00         Category-98       Product-bd79
# 40  2024-11-03 15:58:00        Category-120       Product-d53e
# 41  2024-08-23 23:55:00         Category-76       Product-6e9c
# 42  2024-08-23 23:55:00         Category-77       Product-d09c
# 43  2024-11-06 21:43:00        Category-120       Product-83fd
# 44  2024-02-09 18:33:00         Category-85       Product-d06e
# 45  2024-02-09 18:33:00         Category-77       Product-d09c
# 46  2024-04-12 15:53:00         Category-91       Product-32b3
# 47  2024-04-12 15:53:00        Category-120       Product-7864
# 48  2024-04-12 15:53:00         Category-77       Product-d09c
# 49  2024-07-12 20:50:00         Category-75       Product-4832
#
#    ANONYMIZED BUSINESS ANONYMIZED LOCATION  QUANTITY  UNIT PRICE  \
# 0        Business-de42       Location-1ba8         1       850.0
# 1        Business-de42       Location-1ba8         2      1910.0
# 2        Business-de42       Location-1ba8         1      3670.0
# 3        Business-de42       Location-1ba8         1      2605.0
# 4        Business-de42       Location-1ba8         5      1480.0
# 5        Business-de42       Location-1ba8         1      2605.0
# 6        Business-de42       Location-1ba8         1      1940.0
# 7        Business-de42       Location-1ba8         4      1460.0
# 8        Business-de42       Location-1ba8         1       805.0
# 9        Business-de42       Location-1ba8         1      1350.0
# 10       Business-7488       Location-4ea1         2      1700.0
# 11       Business-7488       Location-4ea1         1      3650.0
# 12       Business-2460       Location-4ea1         1      1800.0
# 13       Business-2460       Location-4ea1         1      4000.0
# 14       Business-aab8       Location-128a         1       815.0
# 15       Business-aab8       Location-128a         1      2500.0
# 16       Business-aab8       Location-128a         1       750.0
# 17       Business-f13b       Location-bb69         1      2255.0
# 18       Business-f13b       Location-bb69         1      2540.0
# 19       Business-f13b       Location-bb69         1      1880.0
# 20       Business-5de0       Location-4ea1         1      2120.0
# 21       Business-5d3e       Location-1979         5      1740.0
# 22       Business-5d3e       Location-1979         5      1695.0
# 23       Business-22a2       Location-c2f2         5      2005.0
# 24       Business-22a2       Location-c2f2         3       640.0
# 25       Business-22a2       Location-c2f2         2      3550.0
# 26       Business-22a2       Location-c2f2         1      1530.0
# 27       Business-22a2       Location-c2f2         5      5870.0
# 28       Business-22a2       Location-c2f2         5      6126.0
# 29       Business-c9c0       Location-128a         2       575.0
# 30       Business-c9c0       Location-128a         2       477.0
# 31       Business-c9c0       Location-128a         1      5330.0
# 32       Business-c9c0       Location-128a         1       695.0
# 33       Business-9b3a       Location-689f         5       935.0
# 34       Business-9b3a       Location-689f         1      3190.0
# 35       Business-28e1       Location-3fc0         1      1520.0
# 36       Business-28e1       Location-3fc0         1      3950.0
# 37       Business-2a37       Location-21c7         2       565.0
# 38       Business-2a37       Location-21c7         5      4400.0
# 39       Business-1510       Location-4ea1         1      1940.0
# 40       Business-1510       Location-4ea1        15      1720.0
# 41       Business-3539       Location-4ea1         1      2560.0
# 42       Business-3539       Location-4ea1         1      2600.0
# 43       Business-e8a1       Location-d32a         2      1780.0
# 44       Business-60b8       Location-d32a         1      1130.0
# 45       Business-60b8       Location-d32a         2      3185.0
# 46       Business-926b       Location-d32a         2       640.0
# 47       Business-926b       Location-d32a         1      2090.0
# 48       Business-926b       Location-d32a         2      2700.0
# 49       Business-755c       Location-1c33         2      4360.0
#
#         Month-Year  Total_Value Day_of_Week  Hour_of_Day       Segment
# 0      August 2024        850.0      Sunday           21  Medium Value
# 1      August 2024       3820.0      Sunday           21  Medium Value
# 2      August 2024       3670.0      Sunday           21  Medium Value
# 3      August 2024       2605.0      Sunday           21  Medium Value
# 4      August 2024       7400.0      Sunday           21  Medium Value
# 5      August 2024       2605.0      Sunday           21  Medium Value
# 6      August 2024       1940.0      Sunday           21  Medium Value
# 7      August 2024       5840.0      Sunday           21  Medium Value
# 8      August 2024        805.0      Sunday           21  Medium Value
# 9      August 2024       1350.0      Sunday           21  Medium Value
# 10     August 2024       3400.0     Tuesday           19    High Value
# 11     August 2024       3650.0     Tuesday           19    High Value
# 12       June 2024       1800.0      Sunday           19    High Value
# 13       June 2024       4000.0      Sunday           19    High Value
# 14   November 2024        815.0      Monday           16    High Value
# 15   November 2024       2500.0      Monday           16    High Value
# 16   November 2024        750.0      Monday           16    High Value
# 17  September 2024       2255.0      Friday            8  Medium Value
# 18  September 2024       2540.0      Friday            8  Medium Value
# 19  September 2024       1880.0      Friday            8  Medium Value
# 20    October 2024       2120.0      Sunday           21    High Value
# 21  September 2024       8700.0    Thursday           19    High Value
# 22  September 2024       8475.0    Thursday           19    High Value
# 23        May 2024      10025.0    Thursday           20    High Value
# 24        May 2024       1920.0    Thursday           20    High Value
# 25        May 2024       7100.0    Thursday           20    High Value
# 26        May 2024       1530.0    Thursday           20    High Value
# 27        May 2024      29350.0    Thursday           20    High Value
# 28        May 2024      30630.0    Thursday           20    High Value
# 29  September 2024       1150.0      Friday           21    High Value
# 30  September 2024        954.0      Friday           21    High Value
# 31  September 2024       5330.0      Friday           21    High Value
# 32  September 2024        695.0      Friday           21    High Value
# 33   February 2024       4675.0      Friday           16  Medium Value
# 34   February 2024       3190.0      Friday           16  Medium Value
# 35       June 2024       1520.0   Wednesday           21  Medium Value
# 36       June 2024       3950.0   Wednesday           21  Medium Value
# 37  September 2024       1130.0    Thursday            9    High Value
# 38  September 2024      22000.0    Thursday            9    High Value
# 39   November 2024       1940.0      Sunday           15  Medium Value
# 40   November 2024      25800.0      Sunday           15  Medium Value
# 41     August 2024       2560.0      Friday           23  Medium Value
# 42     August 2024       2600.0      Friday           23  Medium Value
# 43   November 2024       3560.0   Wednesday           21    High Value
# 44   February 2024       1130.0      Friday           18  Medium Value
# 45   February 2024       6370.0      Friday           18  Medium Value
# 46      April 2024       1280.0      Friday           15  Medium Value
# 47      April 2024       2090.0      Friday           15  Medium Value
# 48      April 2024       5400.0      Friday           15  Medium Value
# 49       July 2024       8720.0      Friday           20  Medium Value
